# %% [markdown]
# <a href="https://colab.research.google.com/github/he-man-david/small-transformer-model-arithmetic-math/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# testing
